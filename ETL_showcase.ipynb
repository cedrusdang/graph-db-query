# %% [markdown]
# **This Notebook is just a presentation of the ETL pipeline, please use ETL.py instead of this**

# %%
import ETL
import time
start_time = time.time()
data = ETL.extract("ARDD_Fatalities_Dec_2024.csv")
data
# Out:
# Please ensure that requirements.txt is already been installed with setup_env.sh
# Begin csv files extraction...
# Finish extraction!
#           ID  Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0          1  20241115   NSW     12  2024     Friday   4:00     Single
# 1          2  20241125   NSW     12  2024     Friday   6:15     Single
# 2          3  20246013   TAS     12  2024     Friday   9:43     Single
# 3          4  20241002   NSW     12  2024     Friday  10:35     Single
# 4          5  20243185   QLD     12  2024     Friday  13:00     Single
# ...      ...       ...   ...    ...   ...        ...    ...        ...
# 10485  10486  20144079    SA      1  2014   Thursday  14:40     Single
# 10486  10487  20145055    WA      1  2014    Tuesday  16:42     Single
# 10487  10488  20144007    SA      1  2014    Tuesday  20:00     Single
# 10488  10489  20145072    WA      1  2014    Tuesday  21:30     Single
# 10489  10490  20145108    WA      1  2014  Wednesday  11:47     Single
#
#        Number Fatalities Bus Involvement  ... Age  National Remoteness Areas  \
# 0                      1              No  ...  74   Inner Regional Australia
# 1                      1              No  ...  19   Inner Regional Australia
# 2                      1              No  ...  33   Inner Regional Australia
# 3                      1              No  ...  32   Outer Regional Australia
# 4                      1              No  ...  61   Inner Regional Australia
# ...                  ...             ...  ...  ..                        ...
# 10485                  1              No  ...  36   Outer Regional Australia
# 10486                  1              No  ...  34  Major Cities of Australia
# 10487                  1              No  ...  82  Major Cities of Australia
# 10488                  1              No  ...  84           Remote Australia
# 10489                  1              No  ...  46  Major Cities of Australia
#
#                                 SA4 Name 2021 National LGA Name 2024  \
# 0                                    Riverina            Wagga Wagga
# 1      Sydney - Baulkham Hills and Hawkesbury             Hawkesbury
# 2                   Launceston and North East      Northern Midlands
# 3                  New England and North West               Armidale
# 4                                   Toowoomba         Lockyer Valley
# ...                                       ...                    ...
# 10485            South Australia - South East           Wattle Range
# 10486                           Perth - Inner              Cambridge
# 10487                        Adelaide - North               Playford
# 10488     Western Australia - Outback (South)              Esperance
# 10489                      Perth - South East                Belmont
#
#               National Road Type  Christmas Period Easter Period    Age Group  \
# 0                  Arterial Road               Yes            No     65_to_74
# 1                     Local Road                No            No     17_to_25
# 2                     Local Road               Yes            No     26_to_39
# 3      National or State Highway                No            No     26_to_39
# 4      National or State Highway                No            No     40_to_64
# ...                          ...               ...           ...          ...
# 10485  National or State Highway                No            No     26_to_39
# 10486  National or State Highway                No            No     26_to_39
# 10487                 Local Road                No            No  75_or_older
# 10488  National or State Highway                No            No  75_or_older
# 10489  National or State Highway               Yes            No     40_to_64
#
#       Day of week Time of day
# 0         Weekday       Night
# 1         Weekday         Day
# 2         Weekday         Day
# 3         Weekday         Day
# 4         Weekday         Day
# ...           ...         ...
# 10485     Weekday         Day
# 10486     Weekday         Day
# 10487     Weekday       Night
# 10488     Weekday       Night
# 10489     Weekday         Day
#
# [10490 rows x 25 columns]

# %%
data = ETL.transform_column_names(data)
data
# Out:
# Begin transform columns' names...
# Finish transform columns' names!
#        fatality_sk  crash_id state  month  year    dayweek   time crash_type  \
# 0                1  20241115   NSW     12  2024     Friday   4:00     Single
# 1                2  20241125   NSW     12  2024     Friday   6:15     Single
# 2                3  20246013   TAS     12  2024     Friday   9:43     Single
# 3                4  20241002   NSW     12  2024     Friday  10:35     Single
# 4                5  20243185   QLD     12  2024     Friday  13:00     Single
# ...            ...       ...   ...    ...   ...        ...    ...        ...
# 10485        10486  20144079    SA      1  2014   Thursday  14:40     Single
# 10486        10487  20145055    WA      1  2014    Tuesday  16:42     Single
# 10487        10488  20144007    SA      1  2014    Tuesday  20:00     Single
# 10488        10489  20145072    WA      1  2014    Tuesday  21:30     Single
# 10489        10490  20145108    WA      1  2014  Wednesday  11:47     Single
#
#        fatalities bus  ... age                        nra  \
# 0               1  No  ...  74   Inner Regional Australia
# 1               1  No  ...  19   Inner Regional Australia
# 2               1  No  ...  33   Inner Regional Australia
# 3               1  No  ...  32   Outer Regional Australia
# 4               1  No  ...  61   Inner Regional Australia
# ...           ...  ..  ...  ..                        ...
# 10485           1  No  ...  36   Outer Regional Australia
# 10486           1  No  ...  34  Major Cities of Australia
# 10487           1  No  ...  82  Major Cities of Australia
# 10488           1  No  ...  84           Remote Australia
# 10489           1  No  ...  46  Major Cities of Australia
#
#                                           sa4                lga  \
# 0                                    Riverina        Wagga Wagga
# 1      Sydney - Baulkham Hills and Hawkesbury         Hawkesbury
# 2                   Launceston and North East  Northern Midlands
# 3                  New England and North West           Armidale
# 4                                   Toowoomba     Lockyer Valley
# ...                                       ...                ...
# 10485            South Australia - South East       Wattle Range
# 10486                           Perth - Inner          Cambridge
# 10487                        Adelaide - North           Playford
# 10488     Western Australia - Outback (South)          Esperance
# 10489                      Perth - South East            Belmont
#
#                        road_type  christmas easter    age_group day_of_week  \
# 0                  Arterial Road        Yes     No     65_to_74     Weekday
# 1                     Local Road         No     No     17_to_25     Weekday
# 2                     Local Road        Yes     No     26_to_39     Weekday
# 3      National or State Highway         No     No     26_to_39     Weekday
# 4      National or State Highway         No     No     40_to_64     Weekday
# ...                          ...        ...    ...          ...         ...
# 10485  National or State Highway         No     No     26_to_39     Weekday
# 10486  National or State Highway         No     No     26_to_39     Weekday
# 10487                 Local Road         No     No  75_or_older     Weekday
# 10488  National or State Highway         No     No  75_or_older     Weekday
# 10489  National or State Highway        Yes     No     40_to_64     Weekday
#
#       time_of_day
# 0           Night
# 1             Day
# 2             Day
# 3             Day
# 4             Day
# ...           ...
# 10485         Day
# 10486         Day
# 10487       Night
# 10488       Night
# 10489         Day
#
# [10490 rows x 25 columns]

# %%
data = ETL.transform_time_to_hour(data)
data = ETL.fix_time_of_day_by_hour(data)
data
# Out:
# Begin transform time column to hour...
# Finish transform time column to hour!
# Fixing time_of_day column based on hour...
# Finished fixing time_of_day column.
#        fatality_sk  crash_id state  month  year    dayweek crash_type  \
# 0                1  20241115   NSW     12  2024     Friday     Single
# 1                2  20241125   NSW     12  2024     Friday     Single
# 2                3  20246013   TAS     12  2024     Friday     Single
# 3                4  20241002   NSW     12  2024     Friday     Single
# 4                5  20243185   QLD     12  2024     Friday     Single
# ...            ...       ...   ...    ...   ...        ...        ...
# 10485        10486  20144079    SA      1  2014   Thursday     Single
# 10486        10487  20145055    WA      1  2014    Tuesday     Single
# 10487        10488  20144007    SA      1  2014    Tuesday     Single
# 10488        10489  20145072    WA      1  2014    Tuesday     Single
# 10489        10490  20145108    WA      1  2014  Wednesday     Single
#
#        fatalities bus heavy_rigid_truck  ...                        nra  \
# 0               1  No                No  ...   Inner Regional Australia
# 1               1  No                No  ...   Inner Regional Australia
# 2               1  No                No  ...   Inner Regional Australia
# 3               1  No                No  ...   Outer Regional Australia
# 4               1  No                No  ...   Inner Regional Australia
# ...           ...  ..               ...  ...                        ...
# 10485           1  No                No  ...   Outer Regional Australia
# 10486           1  No                No  ...  Major Cities of Australia
# 10487           1  No                No  ...  Major Cities of Australia
# 10488           1  No                No  ...           Remote Australia
# 10489           1  No                No  ...  Major Cities of Australia
#
#                                           sa4                lga  \
# 0                                    Riverina        Wagga Wagga
# 1      Sydney - Baulkham Hills and Hawkesbury         Hawkesbury
# 2                   Launceston and North East  Northern Midlands
# 3                  New England and North West           Armidale
# 4                                   Toowoomba     Lockyer Valley
# ...                                       ...                ...
# 10485            South Australia - South East       Wattle Range
# 10486                           Perth - Inner          Cambridge
# 10487                        Adelaide - North           Playford
# 10488     Western Australia - Outback (South)          Esperance
# 10489                      Perth - South East            Belmont
#
#                        road_type  christmas easter    age_group day_of_week  \
# 0                  Arterial Road        Yes     No     65_to_74     Weekday
# 1                     Local Road         No     No     17_to_25     Weekday
# 2                     Local Road        Yes     No     26_to_39     Weekday
# 3      National or State Highway         No     No     26_to_39     Weekday
# 4      National or State Highway         No     No     40_to_64     Weekday
# ...                          ...        ...    ...          ...         ...
# 10485  National or State Highway         No     No     26_to_39     Weekday
# 10486  National or State Highway         No     No     26_to_39     Weekday
# 10487                 Local Road         No     No  75_or_older     Weekday
# 10488  National or State Highway         No     No  75_or_older     Weekday
# 10489  National or State Highway        Yes     No     40_to_64     Weekday
#
#       time_of_day hour
# 0           Night    4
# 1             Day    6
# 2             Day    9
# 3             Day   10
# 4             Day   13
# ...           ...  ...
# 10485         Day   14
# 10486         Day   16
# 10487       Night   20
# 10488       Night   21
# 10489         Day   11
#
# [10490 rows x 25 columns]

# %%
driver = ETL.setup_neo4j()
# Out:
# Begin create NEO4J connection...
# Loading secret keys from .env...
# Connect to local Graph Data base...
# Finish create NEO4J connection!

# %%
# Dims and columns  sets
tables_cols_sets = {
    "date": ["dayweek", "day_of_week", "month", "year", ],
    "crash_type": ["crash_type"],
    "holiday": ["easter", "christmas"],
    "lga": ["lga"],
    "sa4": ["sa4"],
    "nra": ["nra"],
    "state": ["state"],
    "gender": ["gender"],
    "age_group": ["age_group"],
    "road_user": ["road_user"],
    "involvement": ["bus", "heavy_rigid_truck", "articulated_truck"],
    "road_type": ["road_type"],
    "speed_limit": ["speed_limit"],
    "time": ["hour"],
    "crash": ["crash_id"],
    "fatality": ["fatality_sk"]
}

# All dims with sk
dim_names = [
    "date", "crash_type", "holiday", "lga", "sa4", "nra", "state",
    "gender", "age_group", "road_user", "involvement", "road_type"
]
# All dims without sk
dim_names_no_sk = {"speed_limit", "time"}

# Load the dim nodes
for name in dim_names:
    data = ETL.create_table_load(data, tables_cols_sets, name, driver, sk=True)
for name in dim_names_no_sk:
    data = ETL.create_table_load(data, tables_cols_sets, name, driver, sk=False)
# Load the fact nodes
data = ETL.create_table_load(data, tables_cols_sets, "crash", driver, sk=True)
data = ETL.create_table_load(data, tables_cols_sets, "fatality", driver, sk=False)
# Out:
# Begin create table date...
# Finish create table date!
# Save to: csv_files_before_load\date.csv
# Loading nodes of date to NEO4J: 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Begin create table crash_type...
# Finish create table crash_type!
# Save to: csv_files_before_load\crash_type.csv
# Loading nodes of crash_type to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 69.05it/s]
# Begin create table holiday...
# Finish create table holiday!
# Save to: csv_files_before_load\holiday.csv
# Loading nodes of holiday to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 60.46it/s]
# Begin create table lga...
# Finish create table lga!
# Save to: csv_files_before_load\lga.csv
# Loading nodes of lga to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 14.89it/s]
# Begin create table sa4...
# Finish create table sa4!
# Save to: csv_files_before_load\sa4.csv
# Loading nodes of sa4 to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 55.50it/s]
# Begin create table nra...
# Finish create table nra!
# Save to: csv_files_before_load\nra.csv
# Loading nodes of nra to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 73.92it/s]
# Begin create table state...
# Finish create table state!
# Save to: csv_files_before_load\state.csv
# Loading nodes of state to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 62.11it/s]
# Begin create table gender...
# Finish create table gender!
# Save to: csv_files_before_load\gender.csv
# Loading nodes of gender to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 221.65it/s]
# Begin create table age_group...
# Finish create table age_group!
# Save to: csv_files_before_load\age_group.csv
# Loading nodes of age_group to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 499.86it/s]
# Begin create table road_user...
# Finish create table road_user!
# Save to: csv_files_before_load\road_user.csv
# Loading nodes of road_user to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 397.56it/s]
# Begin create table involvement...
# Finish create table involvement!
# Save to: csv_files_before_load\involvement.csv
# Loading nodes of involvement to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 500.27it/s]
# Begin create table road_type...
# Finish create table road_type!
# Save to: csv_files_before_load\road_type.csv
# Loading nodes of road_type to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 500.10it/s]
# Begin create table speed_limit...
# Finish create table speed_limit!
# Save to: csv_files_before_load\speed_limit.csv
# Loading nodes of speed_limit to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 333.30it/s]
# Begin create table time...
# Finish create table time!
# Save to: csv_files_before_load\time.csv
# Loading nodes of time to NEO4J: 100%|██████████| 1/1 [00:00<00:00, 332.59it/s]
# Begin create table crash...
# Finish create table crash!
# Save to: csv_files_before_load\crash.csv
# Loading nodes of crash to NEO4J: 100%|██████████| 10/10 [00:16<00:00,  1.61s/it]
# Begin create table fatality...
# Finish create table fatality!
# Save to: csv_files_before_load\fatality.csv
# Loading nodes of fatality to NEO4J: 100%|██████████| 11/11 [00:18<00:00,  1.64s/it]

# %%
data
# Out:
#        fatality_sk  fatalities  speed_limit  age time_of_day  hour  date_sk  \
# 0                1           1          100   74       Night     4        1
# 1                2           1           80   19         Day     6        1
# 2                3           1           50   33         Day     9        1
# 3                4           1          100   32         Day    10        1
# 4                5           1          100   61         Day    13        1
# ...            ...         ...          ...  ...         ...   ...      ...
# 10485        10486           1          110   36         Day    14      799
# 10486        10487           1           80   34         Day    16      935
# 10487        10488           1           50   82       Night    20      935
# 10488        10489           1          110   84       Night    21      935
# 10489        10490           1          100   46         Day    11     1132
#
#        crash_type_sk  holiday_sk  lga_sk  sa4_sk  nra_sk  state_sk  gender_sk  \
# 0                  2           1     455      60       1         2          2
# 1                  2           2     203      67       1         2          1
# 2                  2           1     351      32       1         6          1
# 3                  2           2      12      49       3         2          1
# 4                  2           2     269      81       1         4          1
# ...              ...         ...     ...     ...     ...       ...        ...
# 10485              2           2     469      63       3         5          2
# 10486              2           2      73      53       2         8          2
# 10487              2           2     368       2       2         5          2
# 10488              2           2     156      86       4         8          2
# 10489              2           1      35      56       2         8          2
#
#        age_group_sk  road_user_sk  involvement_sk  road_type_sk  crash_sk
# 0                 5             1               1             2      8894
# 1                 2             1               1             5      8904
# 2                 3             1               1             5      9653
# 3                 3             1               1             6      8781
# 4                 4             4               1             6      9480
# ...             ...           ...             ...           ...       ...
# 10485             3             1               2             6        79
# 10486             3             3               1             6       147
# 10487             6             6               1             5         7
# 10488             6             1               1             6       162
# 10489             4             3               1             6       190
#
# [10490 rows x 19 columns]

# %%
rel_schema = {
    1: ["IN_DATE", "crash", "crash_sk", "date", "date_sk"],
    2: ["CLASSIFIED_AS", "crash", "crash_sk", "crash_type", "crash_type_sk"],
    3: ["IN_EVENT", "crash", "crash_sk", "holiday", "holiday_sk"],
    4: ["IN_LOCATION", "crash", "crash_sk", "lga", "lga_sk"],
    5: ["IN_SA4", "lga", "lga_sk", "sa4", "sa4_sk"],
    6: ["IN_NRA", "sa4", "sa4_sk", "nra", "nra_sk"],
    7: ["IN_STATE", "nra", "nra_sk", "state", "state_sk"],
    8: ["GENDER_IS", "fatality", "fatality_sk", "gender", "gender_sk"],
    9: ["AGE_IS", "fatality", "fatality_sk", "age_group", "age_group_sk"],
    10: ["ROAD_USER_IS", "fatality", "fatality_sk", "road_user", "road_user_sk"],
    11: ["IN_SPEED_LIMIT", "crash", "crash_sk", "speed_limit", "speed_limit"],
    12: ["DIED_IN", "fatality", "fatality_sk", "crash", "crash_sk"],
    13: ["INVOLVE_WITH", "crash", "crash_sk", "involvement", "involvement_sk"],
    14: ["IN_ROAD_TYPE", "crash", "crash_sk", "road_type", "road_type_sk"],
    15: ["IN_TIME", "crash", "crash_sk", "time", "hour"]
}

ETL.create_rel_load(data, driver, rel_schema)

end_time = time.time()
print(f"--- Total runtime: {end_time - start_time:.2f} seconds ---")
# Out:
# Save to: csv_files_before_load\IN_DATE.csv
# Save to: csv_files_before_load\CLASSIFIED_AS.csv
# Save to: csv_files_before_load\IN_EVENT.csv
# Save to: csv_files_before_load\IN_LOCATION.csv
# Save to: csv_files_before_load\IN_SA4.csv
# Save to: csv_files_before_load\IN_NRA.csv
# Save to: csv_files_before_load\IN_STATE.csv
# Save to: csv_files_before_load\GENDER_IS.csv
# Save to: csv_files_before_load\AGE_IS.csv
# Save to: csv_files_before_load\ROAD_USER_IS.csv
# Save to: csv_files_before_load\IN_SPEED_LIMIT.csv
# Save to: csv_files_before_load\DIED_IN.csv
# Save to: csv_files_before_load\INVOLVE_WITH.csv
# Save to: csv_files_before_load\IN_ROAD_TYPE.csv
# Save to: csv_files_before_load\IN_TIME.csv
# Loading IN_DATE: 100%|██████████| 11/11 [00:20<00:00,  1.89s/it]
# Loading CLASSIFIED_AS: 100%|██████████| 11/11 [00:00<00:00, 56.01it/s]
# Loading IN_EVENT: 100%|██████████| 11/11 [00:00<00:00, 54.85it/s]
# Loading IN_LOCATION: 100%|██████████| 11/11 [00:21<00:00,  1.91s/it]
# Loading IN_SA4: 100%|██████████| 11/11 [00:01<00:00,  8.85it/s]
# Loading IN_NRA: 100%|██████████| 11/11 [00:00<00:00, 31.20it/s]
# Loading IN_STATE: 100%|██████████| 11/11 [00:00<00:00, 50.73it/s]
# Loading GENDER_IS: 100%|██████████| 11/11 [00:00<00:00, 57.03it/s]
# Loading AGE_IS: 100%|██████████| 11/11 [00:00<00:00, 54.38it/s]
# Loading ROAD_USER_IS: 100%|██████████| 11/11 [00:00<00:00, 53.30it/s]
# Loading IN_SPEED_LIMIT: 100%|██████████| 11/11 [00:00<00:00, 52.42it/s]
# Loading DIED_IN: 100%|██████████| 11/11 [00:21<00:00,  1.99s/it]
# Loading INVOLVE_WITH: 100%|██████████| 11/11 [00:00<00:00, 47.88it/s]
# Loading IN_ROAD_TYPE: 100%|██████████| 11/11 [00:00<00:00, 53.92it/s]
# Loading IN_TIME: 100%|██████████| 11/11 [00:00<00:00, 47.77it/s]
# --- Total runtime: 105.45 seconds ---
